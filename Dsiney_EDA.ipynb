# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
disney = pd.read_csv("disney_movies.csv")
disney
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
disney.shape
# Out:
# (579, 6)

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %%
disney.describe()
# Out:
#         total_gross  inflation_adjusted_gross
# count  5.790000e+02              5.790000e+02
# mean   6.470179e+07              1.187625e+08
# std    9.301301e+07              2.860853e+08
# min    0.000000e+00              0.000000e+00
# 25%    1.278886e+07              2.274123e+07
# 50%    3.070245e+07              5.515978e+07
# 75%    7.570903e+07              1.192020e+08
# max    9.366622e+08              5.228953e+09

# %% [markdown]
# ### MAXIMUM AND MINIMUM GROSSING MOVIES¶

# %%
disney.columns
# Out:
# Index(['movie_title', 'release_date', 'genre', 'mpaa_rating', 'total_gross',
#        'inflation_adjusted_gross'],
#       dtype='object')

# %%
print("------------------max grossing--------------------")
print(disney[['total_gross','inflation_adjusted_gross','movie_title']].max())
print("------------------min grossing--------------------")
print(disney[['total_gross','inflation_adjusted_gross','movie_title']].min())
# Out:
# ------------------max grossing--------------------
# total_gross                       936662225
# inflation_adjusted_gross         5228953251
# movie_title                 crazy/beautiful
# dtype: object
# ------------------min grossing--------------------
# total_gross                              0
# inflation_adjusted_gross                 0
# movie_title                 101 Dalmatians
# dtype: object

# %% [markdown]
# ### Relationships Between Total Gross and Other Fields

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,3,1])
ax = sns.stripplot(x="genre", y="total_gross", data=disney, ax=ax)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,3,1])
ax = sns.stripplot(x="mpaa_rating", y="total_gross", data=disney, ax=ax)

# %%
disney.plot(x='release_date',y='total_gross',kind='scatter')
# Out:
# <Axes: xlabel='release_date', ylabel='total_gross'>

# %%
disney.plot(x='release_date',y='total_gross',kind='line')
# Out:
# <Axes: xlabel='release_date'>

# %% [markdown]
# ### Genre

# %%
disney.groupby("genre").describe()
# Out:
#                     total_gross                                          \
#                           count          mean           std         min
# genre
# Action                     40.0  1.046141e+08  1.400622e+08         0.0
# Adventure                 129.0  1.270471e+08  1.421435e+08      2815.0
# Black Comedy                3.0  3.251440e+07  1.803695e+07  17105219.0
# Comedy                    182.0  4.461329e+07  4.555087e+07     45779.0
# Concert/Performance         2.0  5.172823e+07  1.916761e+07  38174685.0
# Documentary                16.0  1.129285e+07  1.028833e+07     20521.0
# Drama                     114.0  3.602608e+07  3.879405e+07         0.0
# Horror                      6.0  1.451148e+07  9.377734e+06   4877567.0
# Musical                    16.0  7.233026e+07  6.515831e+07   5632086.0
# Romantic Comedy            23.0  5.009595e+07  4.947553e+07    468240.0
# Thriller/Suspense          24.0  5.861694e+07  7.089503e+07   2154540.0
# ...

# %%
genre_group = disney.groupby("genre")

# %%
for i in set(disney["genre"]):
    print("-"*16, i, "-"*16)
    grp = disney.where(disney["genre"]==i).dropna()
    print("\n\n----MAX----\n")
    print(grp.max())
    print("\n\n----MIN----\n")
    print(grp.min())
    print("\n\n")
# Out:
# ---------------- Adventure ----------------
#
#
# ----MAX----
#
# movie_title                     Zootopia
# release_date                  2016-12-16
# genre                          Adventure
# mpaa_rating                            R
# total_gross                  936662225.0
# inflation_adjusted_gross    2188229052.0
# dtype: object
#
#
# ----MIN----
#
# movie_title                 1492: Conquest of Paradise
# release_date                                1940-02-09
# genre                                        Adventure
# mpaa_rating                                          G
# total_gross                                     2815.0
# inflation_adjusted_gross                        2984.0
# dtype: object
#
#
#
# ---------------- Romantic Comedy ----------------
#
#
# ----MAX----
#
# movie_title                 While You Were Sleeping
# release_date                             2014-08-08
# genre                               Romantic Comedy
# ...

# %%
for i in set(disney["genre"]):
#     print("-"*16, i, "-"*16)
#     fig=plt.figure()
#     ax=fig.add_axes([0,0,1,1])
    grp = disney.where(disney["genre"]==i).dropna()
    grp.plot(x="release_date", y="total_gross", title="Release Date Vs Total Gross For %s Genre"%(i))
#    ax.set_title("Release Date Vs Total Gross For %s Genre"%(i))
#    ax.plot(x=grp["release_date"], y=grp["total_gross"])

# %%
for i in set(disney["genre"]):
    grp = disney.where(disney["genre"]==i).dropna()
    grp.plot(kind="scatter", x="release_date", y="total_gross", title="Release Date Vs Total Gross For %s Genre"%(i))

# %%
print(disney.groupby("genre")["movie_title"].count())
# Out:
# genre
# Action                  40
# Adventure              129
# Black Comedy             3
# Comedy                 182
# Concert/Performance      2
# Documentary             16
# Drama                  114
# Horror                   6
# Musical                 16
# Romantic Comedy         23
# Thriller/Suspense       24
# Western                  7
# Name: movie_title, dtype: int64

# %% [markdown]
# ### MPAA Rating

# %%
mpaa_grp=disney.groupby("mpaa_rating")

# %%
mpaa_grp.describe()
# Out:
#             total_gross                                                      \
#                   count          mean           std        min          25%
# mpaa_rating
# G                  86.0  9.209061e+07  9.203581e+07  6197866.0  25788482.50
# Not Rated           3.0  5.046259e+07  7.926324e+07   314000.0   4772384.50
# PG                187.0  7.362521e+07  8.311639e+07     2815.0  20184496.50
# PG-13             145.0  8.118074e+07  1.311012e+08    48658.0  13906394.00
# R                 102.0  2.936536e+07  3.397795e+07    34368.0   7262560.25
#
#                                                    inflation_adjusted_gross  \
#                     50%           75%          max                    count
# mpaa_rating
# G            65140890.5  1.183511e+08  422780140.0                     86.0
# Not Rated     9230769.0  7.553688e+07  141843000.0                      3.0
# PG           50047179.0  9.046539e+07  486295561.0                    187.0
# ...

# %%
mpaa_grp.plot(x="release_date")
# Out:
# mpaa_rating
# G            Axes(0.125,0.11;0.775x0.77)
# Not Rated    Axes(0.125,0.11;0.775x0.77)
# PG           Axes(0.125,0.11;0.775x0.77)
# PG-13        Axes(0.125,0.11;0.775x0.77)
# R            Axes(0.125,0.11;0.775x0.77)
# dtype: object
